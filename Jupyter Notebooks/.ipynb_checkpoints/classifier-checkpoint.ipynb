# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # Import the Datasets

# %%
peopleFilepath = './Data/pickledPeople.pkl'
voteFilepath = './Data/pickledVotes_unpacked.pkl'
routeFilepath = './Data/pickledRoutes_unpacked.pkl'

people = pd.read_pickle(peopleFilepath)
votes = pd.read_pickle(voteFilepath)
routes = pd.read_pickle(routeFilepath)

# %% [markdown]
# # Define function to find people with common routes

# %%
# Function to find what breadcrumb the route is in
def find_bc(areaUrl, routes):
    print("Finding the Breadcrumb for", routes.loc[areaUrl]['name'])
    bc = ['bc1', 'bc2', 'bc3']
    for i in range(len(routes)):
        for j in bc:
            if routes.iloc[i][j]==areaUrl:
                print(routes.loc[areaUrl]['name'], "breadcrumb is:", j)
                return j
    

# Function to find all common people between N most-popular routes
def findCommonPeople(areaUrl, breadcrumbTier, nRoutes, routes, people, verbose=True):
    areaRoutes = routes.loc[routes[breadcrumbTier]==areaUrl]
    areaRoutes = areaRoutes.sort_values('numQualityVotes', ascending=False)
    areaRoutes = areaRoutes[:nRoutes]
    
    subPeople = set([])
    
    # Filter the people dataset to only include those with at least nRoutes starRatings
    people = people.loc[people['numStarRatings']>=nRoutes*5]
            
    for i in range(len(areaRoutes)):
        tempSet=[]
        if verbose:
            print("Parsing peopleDF for route", i+1, "of", nRoutes)
        for j in range(len(people)):
            if areaRoutes.index[i] in people.iloc[j]['starRatings']:
                tempSet.append(people.index[j])
                if verbose:
                    print(j/len(people), end='\r')        
        if i==0:
            subPeople=set(tempSet)
        else:
            subPeople = subPeople.intersection(set(tempSet))
            
    if verbose:
        print(len(subPeople),"have climbed the", nRoutes, "most-rated climbs at", areaUrl) 
        print()

    return subPeople

def print_header(a, areaUrlList):
    if len(areaUrlList) >= 10 and a < 10:
        print("##########################")
        print("## STARTING AREA", a+1, "/", len(areaUrlList), "##")
        print("##########################")
        print()
        
    elif len(areaUrlList) >= 10 and a >=10:
        print("###########################")
        print("## STARTING AREA", a+1, "/", len(areaUrlList), "##")
        print("###########################")
        print()
        
    else:
        print("#########################")
        print("## STARTING AREA", a+1, "/", len(areaUrlList), "##")
        print("#########################")
        print()

# %%
def plot_num_common_people(areaUrlList, breadcrumbList, labelList, nRoutesLower=1, nRoutesUpper=10, routes=routes, people=people):
    
    areas = []
    for a in range(len(areaUrlList)):
        
        # Aesthetics
        print_header(a, areaUrlList)
        
        numPeople = []
        for i in range(nRoutesLower, nRoutesUpper+1):
            print("PERFORMING ITERATION", i-nRoutesLower+1, "OF", nRoutesUpper-nRoutesLower+1)
            numPeople.append(len(findCommonPeople(areaUrlList[a], breadcrumbList[a], i, routes, people, verbose=True)))
        areas.append(numPeople)
        
    # Plot the areas
    fig, ax = plt.subplots(figsize=(10,6))
    x = range(nRoutesLower, nRoutesUpper+1)
    
    for i in range(len(areas)):
        ax.plot(x, areas[i], '-o', label=labelList[i])
    ax.set_title("# Routes vs # Common Users")
    ax.set_xlabel("Number of Routes", fontsize=14)
    ax.set_ylabel("Number of People Who Rated All Climbs", fontsize=14)
    ax.set_xticks(list(range(nRoutesLower, nRoutesUpper+1)))
    ax.legend()
    
    plt.show()
    
################################
## ## ## ## ## ## ## ## ## ## ##
################################

# Areas to search
areaList = ['https://www.mountainproject.com/area/105833381/yosemite-national-park',
            'https://www.mountainproject.com/area/105744246/eldorado-canyon-sp',
            'https://www.mountainproject.com/area/105744222/boulder-canyon',
            'https://www.mountainproject.com/area/105745528/avalon',
           'https://www.mountainproject.com/area/105798167/the-gunks',
           'https://www.mountainproject.com/area/105720495/joshua-tree-national-park',
           'https://www.mountainproject.com/area/105841134/red-river-gorge',
           'https://www.mountainproject.com/area/105716763/indian-creek',
           'https://www.mountainproject.com/area/105788989/smith-rock',
           'https://www.mountainproject.com/area/105797700/flatirons',
           'https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch',
           'https://www.mountainproject.com/area/105744460/rmnp-rock']

# List of their breadcrumb positions
bcList = ['bc2', 'bc3', 'bc3', 'bc4', 'bc2', 'bc2', 'bc2', 'bc3', 'bc3', 'bc3', 'bc2', 'bc3']

# List of area labels
labelList = ['Yosemite NP',
             'Eldorado Canyon SP',
             'Boulder Canyon',
             'Avalon Crag',
             'The Gunks',
             'Joshua Tree NP',
             'Red River Gorge',
             'Indian Creek',
            'Smith Rock',
            'Flatirons',
            'Horseshoe Canyon Ranch',
            'Rocky Mountain NP']

plot_num_common_people(areaList, bcList, labelList)
# Out:
# ##########################
# ## STARTING AREA 1 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 1156 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 446 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 280 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 161 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 129 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 86 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 73 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 47 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 37 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 33 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105833381/yosemite-national-park
#
# ##########################
# ## STARTING AREA 2 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 1536 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 734 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 443 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 304 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 272 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 199 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 171 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 146 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 127 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 95 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105744246/eldorado-canyon-sp
#
# ##########################
# ## STARTING AREA 3 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 685 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 360 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 130 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 81 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 49 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 33 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 20 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 19 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 15 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 14 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105744222/boulder-canyon
#
# ##########################
# ## STARTING AREA 4 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 1081 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 472 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 298 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 231 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 178 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 144 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 127 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 97 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 81 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 75 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105798167/the-gunks
#
# ##########################
# ## STARTING AREA 5 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 1120 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 588 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 329 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 175 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 94 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 75 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 52 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 47 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 42 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 31 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105720495/joshua-tree-national-park
#
# ##########################
# ## STARTING AREA 6 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 692 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 449 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 199 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 163 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 89 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 46 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 33 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 25 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 21 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 18 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105841134/red-river-gorge
#
# ##########################
# ## STARTING AREA 7 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 974 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 696 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 414 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 259 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 161 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 116 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 87 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 76 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 60 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 36 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105716763/indian-creek
#
# ##########################
# ## STARTING AREA 8 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 863 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 268 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 127 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 81 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 66 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 35 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 28 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 19 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 15 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 12 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105788989/smith-rock
#
# ##########################
# ## STARTING AREA 9 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 905 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 433 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 198 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 33 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 16 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 9 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 5 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 5 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 5 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 1 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105797700/flatirons
#
# ##########################
# ## STARTING AREA 10 / 10 ##
# ##########################
#
# PERFORMING ITERATION 1 OF 10
# Parsing peopleDF for route 1 of 1
# 316 have climbed the 1 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 2 OF 10
# Parsing peopleDF for route 1 of 2
# Parsing peopleDF for route 2 of 2
# 147 have climbed the 2 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 3 OF 10
# Parsing peopleDF for route 1 of 3
# Parsing peopleDF for route 2 of 3
# Parsing peopleDF for route 3 of 3
# 79 have climbed the 3 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 4 OF 10
# Parsing peopleDF for route 1 of 4
# Parsing peopleDF for route 2 of 4
# Parsing peopleDF for route 3 of 4
# Parsing peopleDF for route 4 of 4
# 47 have climbed the 4 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 5 OF 10
# Parsing peopleDF for route 1 of 5
# Parsing peopleDF for route 2 of 5
# Parsing peopleDF for route 3 of 5
# Parsing peopleDF for route 4 of 5
# Parsing peopleDF for route 5 of 5
# 36 have climbed the 5 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 6 OF 10
# Parsing peopleDF for route 1 of 6
# Parsing peopleDF for route 2 of 6
# Parsing peopleDF for route 3 of 6
# Parsing peopleDF for route 4 of 6
# Parsing peopleDF for route 5 of 6
# Parsing peopleDF for route 6 of 6
# 26 have climbed the 6 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 7 OF 10
# Parsing peopleDF for route 1 of 7
# Parsing peopleDF for route 2 of 7
# Parsing peopleDF for route 3 of 7
# Parsing peopleDF for route 4 of 7
# Parsing peopleDF for route 5 of 7
# Parsing peopleDF for route 6 of 7
# Parsing peopleDF for route 7 of 7
# 19 have climbed the 7 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 8 OF 10
# Parsing peopleDF for route 1 of 8
# Parsing peopleDF for route 2 of 8
# Parsing peopleDF for route 3 of 8
# Parsing peopleDF for route 4 of 8
# Parsing peopleDF for route 5 of 8
# Parsing peopleDF for route 6 of 8
# Parsing peopleDF for route 7 of 8
# Parsing peopleDF for route 8 of 8
# 13 have climbed the 8 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 9 OF 10
# Parsing peopleDF for route 1 of 9
# Parsing peopleDF for route 2 of 9
# Parsing peopleDF for route 3 of 9
# Parsing peopleDF for route 4 of 9
# Parsing peopleDF for route 5 of 9
# Parsing peopleDF for route 6 of 9
# Parsing peopleDF for route 7 of 9
# Parsing peopleDF for route 8 of 9
# Parsing peopleDF for route 9 of 9
# 8 have climbed the 9 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
#
# PERFORMING ITERATION 10 OF 10
# Parsing peopleDF for route 1 of 10
# Parsing peopleDF for route 2 of 10
# Parsing peopleDF for route 3 of 10
# Parsing peopleDF for route 4 of 10
# Parsing peopleDF for route 5 of 10
# Parsing peopleDF for route 6 of 10
# Parsing peopleDF for route 7 of 10
# Parsing peopleDF for route 8 of 10
# Parsing peopleDF for route 9 of 10
# Parsing peopleDF for route 10 of 10
# 5 have climbed the 10 most-rated climbs at https://www.mountainproject.com/area/105903004/horseshoe-canyon-ranch
